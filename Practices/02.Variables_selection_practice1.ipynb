# %% [markdown]
# # Trabajo ML

# %% [markdown]
# ## Importamos las librerías necesarias

# %% [markdown]
# #### Librerías básicas para el tratamiento con datos y posteriores gráficos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #### Importamos funciones que iremos necesitando a lo largo del trabajo

# %%
from sklearn.utils import resample

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.preprocessing import LabelEncoder

# Librería necesaria para poder separar en conjuntos de training y testing
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Importamos también una librería que nos ayudará a codificar las variables categóricas

# %%
import category_encoders as ce

# %% [markdown]
# #### Importamos por otro lado la función tree necesaria para el posterior tree decision model

# %%
from sklearn import tree

# %% [markdown]
# #### Importamos las funciones necesarias para después poder hallar las medidas necesarias

# %%
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, roc_curve, precision_score, accuracy_score, f1_score

# %%
from sklearn.feature_selection import SelectFromModel, RFE

# %% [markdown]
# #### Mostramos a continuación la creación de dos funciones propias que se han utilizado para encapsular código.

# %%
# Creamos la función evaluate_model que nos servirá más adelante para poder ver los valores de 
# diferentes medidas obtenidas por el modelo
def evaluate_model(ytest, ypred, ypred_proba = None):
    if ypred_proba is not None:
        print('ROC-AUC score of the model: {}'.format(roc_auc_score(ytest, ypred_proba[:, 1])))
    print('Accuracy of the model: {}\n'.format(accuracy_score(ytest, ypred)))
    print('Classification report: \n{}\n'.format(classification_report(ytest, ypred)))
    print('Confusion matrix: \n{}\n'.format(confusion_matrix(ytest, ypred)))

# %% [markdown]
# ## Lectura del fichero csv

# %%
df_selected = pd.read_csv("../data/df_selected.csv")

# %%
# Echamos un vistazo rápido a la pinta que tiene el data frame
df_selected
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0         11575.0      11575.0          11575.0    36      7.35       359.26
# 1          7200.0       7200.0           7200.0    36     24.85       285.70
# 2          7500.0       7500.0           7500.0    36      7.35       232.79
# 3         10000.0      10000.0          10000.0    60     16.02       243.29
# 4         14000.0      14000.0          14000.0    36     16.02       492.34
# ...           ...          ...              ...   ...       ...          ...
# 442330    11575.0      11575.0          11575.0    36     15.59       404.61
# 442331    12000.0      12000.0          12000.0    36     11.99       398.52
# 442332    13000.0      13000.0          13000.0    60     15.99       316.07
# 442333    12000.0      12000.0          12000.0    60     19.99       317.86
# 442334    20000.0      20000.0          20000.0    36     11.99       664.20
#
#        grade sub_grade  emp_length home_ownership  ...  application_type  \
# 0          A        A4           6            OWN  ...                 0
# 1          E        E3           2           RENT  ...                 0
# 2          A        A4           7       MORTGAGE  ...                 0
# 3          C        C5           7           RENT  ...                 0
# 4          C        C5           7       MORTGAGE  ...                 0
# ...      ...       ...         ...            ...  ...               ...
# 442330     D        D1          10           RENT  ...                 0
# 442331     B        B5           1       MORTGAGE  ...                 0
# 442332     D        D2           5           RENT  ...                 0
# 442333     E        E3           1           RENT  ...                 0
# 442334     B        B5          10           RENT  ...                 0
#
#         acc_open_past_24mths  mort_acc pub_rec_bankruptcies tax_liens  \
# 0                        8.0       2.0                  1.0       0.0
# 1                        2.0       0.0                  0.0       0.0
# 2                       13.0       4.0                  0.0       0.0
# 3                        7.0       0.0                  2.0       0.0
# 4                        5.0       1.0                  0.0       0.0
# ...                      ...       ...                  ...       ...
# 442330                   1.0       0.0                  0.0       0.0
# 442331                  11.0       1.0                  0.0       0.0
# 442332                   7.0       0.0                  1.0       0.0
# 442333                   6.0       0.0                  0.0       0.0
# 442334                   1.0       0.0                  0.0       1.0
#
#         disbursement_method  issue_month  issue_year  earliest_cr_year  \
# 0                         0          Jun        2017              1994
# 1                         0          Jun        2017              2000
# 2                         0          Jun        2017              2013
# 3                         0          Jun        2017              2006
# 4                         0          Jun        2017              2008
# ...                     ...          ...         ...               ...
# 442330                    0          Jan        2015              1999
# 442331                    0          Jan        2015              1995
# 442332                    0          Jan        2015              2003
# 442333                    0          Jan        2015              2003
# 442334                    0          Jan        2015              2001
#
#         credit_history
# 0                   23
# 1                   17
# 2                    4
# 3                   11
# 4                    9
# ...                ...
# 442330              16
# 442331              20
# 442332              12
# 442333              12
# 442334              14
#
# [442335 rows x 35 columns]

# %% [markdown]
# #### Vamos ahora a mirar qué pinta tienen las variables del dataset. Para ello utilizaremos la función describe(). Añadiremos también un  include = "all" para obligar a que me incluya todas las columnas del dataset en el describe().

# %%
df_selected.describe(include = "all")
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv           term  \
# count   442335.000000  442335.000000    442335.000000  442335.000000
# unique            NaN            NaN              NaN            NaN
# top               NaN            NaN              NaN            NaN
# freq              NaN            NaN              NaN            NaN
# mean     14566.416856   14566.416856     14561.066882      42.140378
# std       8500.018979    8500.018979      8496.756229      10.472109
# min       1000.000000    1000.000000       900.000000      36.000000
# 25%       8000.000000    8000.000000      8000.000000      36.000000
# 50%      12500.000000   12500.000000     12500.000000      36.000000
# 75%      20000.000000   20000.000000     20000.000000      60.000000
# max      40000.000000   40000.000000     40000.000000      60.000000
#
#              int_rate    installment   grade sub_grade     emp_length  \
# count   442335.000000  442335.000000  442335    442335  442335.000000
# unique            NaN            NaN       7        35            NaN
# top               NaN            NaN       C        C1            NaN
# freq              NaN            NaN  124885     26548            NaN
# mean        13.255884     439.935320     NaN       NaN       5.767755
# std          4.471144     252.505972     NaN       NaN       3.722447
# min          5.320000      14.010000     NaN       NaN       0.000000
# 25%          9.990000     256.900000     NaN       NaN       2.000000
# 50%         12.990000     378.760000     NaN       NaN       6.000000
# 75%         15.990000     579.720000     NaN       NaN      10.000000
# max         30.990000    1714.540000     NaN       NaN      10.000000
#
#        home_ownership  ...  application_type  acc_open_past_24mths  \
# count          442335  ...     442335.000000         442335.000000
# unique              4  ...               NaN                   NaN
# top          MORTGAGE  ...               NaN                   NaN
# freq           220364  ...               NaN                   NaN
# mean              NaN  ...          0.002258              4.795908
# std               NaN  ...          0.047470              3.143748
# min               NaN  ...          0.000000              0.000000
# 25%               NaN  ...          0.000000              3.000000
# 50%               NaN  ...          0.000000              4.000000
# 75%               NaN  ...          0.000000              6.000000
# max               NaN  ...          1.000000             53.000000
#
#              mort_acc pub_rec_bankruptcies      tax_liens  \
# count   442335.000000        442335.000000  442335.000000
# unique            NaN                  NaN            NaN
# top               NaN                  NaN            NaN
# freq              NaN                  NaN            NaN
# mean         1.776111             0.147868       0.056475
# std          2.089641             0.397284       0.419215
# min          0.000000             0.000000       0.000000
# 25%          0.000000             0.000000       0.000000
# 50%          1.000000             0.000000       0.000000
# 75%          3.000000             0.000000       0.000000
# max         47.000000            12.000000      85.000000
#
#         disbursement_method  issue_month     issue_year  earliest_cr_year  \
# count         442335.000000       442335  442335.000000     442335.000000
# unique                  NaN           12            NaN               NaN
# top                     NaN          Oct            NaN               NaN
# freq                    NaN        56111            NaN               NaN
# mean               0.000020          NaN    2014.599414       1998.159006
# std                0.004511          NaN       0.670304          7.464446
# min                0.000000          NaN    2014.000000       1944.000000
# 25%                0.000000          NaN    2014.000000       1994.000000
# 50%                0.000000          NaN    2015.000000       2000.000000
# 75%                0.000000          NaN    2015.000000       2003.000000
# max                1.000000          NaN    2017.000000       2014.000000
#
#         credit_history
# count    442335.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean         16.440408
# std           7.429709
# min           3.000000
# 25%          11.000000
# 50%          15.000000
# 75%          20.000000
# max          70.000000
#
# [11 rows x 35 columns]

# %%
# filtro el df_selected en función de si la variable loan_status toma el valor 0 o 1
df_major = df_selected[df_selected.loan_status == 0]
df_minor = df_selected[df_selected.loan_status == 1]

# %%
df_minor_upsmapled = resample(df_minor, replace = True, n_samples = 358436, random_state = 12345)
df_minor_upsmapled
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 400464    28250.0      28250.0          28250.0    36     15.61       987.76
# 366148    12175.0      12175.0          12175.0    60     25.80       363.09
# 22099      2000.0       2000.0           2000.0    36     18.54        72.85
# 396340     5000.0       5000.0           5000.0    36     14.65       172.48
# 32729     12400.0      12400.0          12400.0    60      8.67       255.43
# ...           ...          ...              ...   ...       ...          ...
# 157970    21075.0      21075.0          20975.0    60     19.47       552.17
# 243800    10000.0      10000.0          10000.0    36     12.05       332.39
# 21700      5825.0       5825.0           5825.0    36     18.54       212.17
# 236605    35000.0      35000.0          34750.0    36     14.48      1204.40
# 236034    18000.0      18000.0          18000.0    36     14.48       619.41
#
#        grade sub_grade  emp_length home_ownership  ...  application_type  \
# 400464     D        D1           2       MORTGAGE  ...                 0
# 366148     G        G1           1           RENT  ...                 0
# 22099      E        E1           2       MORTGAGE  ...                 0
# 396340     C        C5           6            OWN  ...                 0
# 32729      B        B1           1           RENT  ...                 0
# ...      ...       ...         ...            ...  ...               ...
# 157970     D        D5           1            OWN  ...                 0
# 243800     C        C1           1            OWN  ...                 0
# 21700      E        E1          10            OWN  ...                 0
# 236605     C        C5           1       MORTGAGE  ...                 0
# 236034     C        C5           2       MORTGAGE  ...                 0
#
#         acc_open_past_24mths  mort_acc pub_rec_bankruptcies tax_liens  \
# 400464                   9.0       3.0                  0.0       0.0
# 366148                   8.0       1.0                  0.0       0.0
# 22099                   20.0       2.0                  1.0       0.0
# 396340                   3.0       0.0                  0.0       0.0
# 32729                    1.0       0.0                  0.0       0.0
# ...                      ...       ...                  ...       ...
# 157970                   4.0       6.0                  0.0       0.0
# 243800                   3.0       0.0                  0.0       0.0
# 21700                    4.0       0.0                  0.0       2.0
# 236605                   5.0       0.0                  0.0       1.0
# 236034                   7.0       1.0                  0.0       1.0
#
#         disbursement_method  issue_month  issue_year  earliest_cr_year  \
# 400464                    0          Apr        2015              1994
# 366148                    0          May        2015              1997
# 22099                     0          Dec        2014              1988
# 396340                    0          Mar        2015              1981
# 32729                     0          Nov        2014              1983
# ...                     ...          ...         ...               ...
# 157970                    0          May        2014              1994
# 243800                    0          Dec        2015              2005
# 21700                     0          Dec        2014              2003
# 236605                    0          Dec        2015              2000
# 236034                    0          Dec        2015              2005
#
#         credit_history
# 400464              21
# 366148              18
# 22099               26
# 396340              34
# 32729               31
# ...                ...
# 157970              20
# 243800              10
# 21700               11
# 236605              15
# 236034              10
#
# [358436 rows x 35 columns]

# %%
df_minor_upsmapled = pd.concat([df_minor_upsmapled, df_major])
df_minor_upsmapled
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 400464    28250.0      28250.0          28250.0    36     15.61       987.76
# 366148    12175.0      12175.0          12175.0    60     25.80       363.09
# 22099      2000.0       2000.0           2000.0    36     18.54        72.85
# 396340     5000.0       5000.0           5000.0    36     14.65       172.48
# 32729     12400.0      12400.0          12400.0    60      8.67       255.43
# ...           ...          ...              ...   ...       ...          ...
# 442326    13150.0      13150.0          13150.0    60     14.99       312.77
# 442327    12000.0      12000.0          12000.0    36      9.49       384.34
# 442328     4000.0       4000.0           4000.0    36      8.67       126.59
# 442330    11575.0      11575.0          11575.0    36     15.59       404.61
# 442334    20000.0      20000.0          20000.0    36     11.99       664.20
#
#        grade sub_grade  emp_length home_ownership  ...  application_type  \
# 400464     D        D1           2       MORTGAGE  ...                 0
# 366148     G        G1           1           RENT  ...                 0
# 22099      E        E1           2       MORTGAGE  ...                 0
# 396340     C        C5           6            OWN  ...                 0
# 32729      B        B1           1           RENT  ...                 0
# ...      ...       ...         ...            ...  ...               ...
# 442326     C        C5           8       MORTGAGE  ...                 0
# 442327     B        B2           4           RENT  ...                 0
# 442328     B        B1          10       MORTGAGE  ...                 0
# 442330     D        D1          10           RENT  ...                 0
# 442334     B        B5          10           RENT  ...                 0
#
#         acc_open_past_24mths  mort_acc pub_rec_bankruptcies tax_liens  \
# 400464                   9.0       3.0                  0.0       0.0
# 366148                   8.0       1.0                  0.0       0.0
# 22099                   20.0       2.0                  1.0       0.0
# 396340                   3.0       0.0                  0.0       0.0
# 32729                    1.0       0.0                  0.0       0.0
# ...                      ...       ...                  ...       ...
# 442326                   0.0       3.0                  0.0       0.0
# 442327                   3.0       0.0                  0.0       0.0
# 442328                   8.0       1.0                  1.0       0.0
# 442330                   1.0       0.0                  0.0       0.0
# 442334                   1.0       0.0                  0.0       1.0
#
#         disbursement_method  issue_month  issue_year  earliest_cr_year  \
# 400464                    0          Apr        2015              1994
# 366148                    0          May        2015              1997
# 22099                     0          Dec        2014              1988
# 396340                    0          Mar        2015              1981
# 32729                     0          Nov        2014              1983
# ...                     ...          ...         ...               ...
# 442326                    0          Jan        2015              1994
# 442327                    0          Jan        2015              2006
# 442328                    0          Jan        2015              2002
# 442330                    0          Jan        2015              1999
# 442334                    0          Jan        2015              2001
#
#         credit_history
# 400464              21
# 366148              18
# 22099               26
# 396340              34
# 32729               31
# ...                ...
# 442326              21
# 442327               9
# 442328              13
# 442330              16
# 442334              14
#
# [703771 rows x 35 columns]

# %%
df_minor_upsmapled.loan_status.value_counts()
# Out:
# 1    358436
# 0    345335
# Name: loan_status, dtype: int64

# %%
df_minor_upsmapled.dtypes
# Out:
# loan_amnt               float64
# funded_amnt             float64
# funded_amnt_inv         float64
# term                      int64
# int_rate                float64
# installment             float64
# grade                    object
# sub_grade                object
# emp_length                int64
# home_ownership           object
# annual_inc              float64
# verification_status       int64
# loan_status               int64
# purpose                  object
# addr_state               object
# dti                     float64
# delinq_2yrs             float64
# fico_range_low          float64
# fico_range_high         float64
# open_acc                float64
# pub_rec                 float64
# revol_bal               float64
# revol_util              float64
# total_acc               float64
# initial_list_status       int64
# application_type          int64
# acc_open_past_24mths    float64
# mort_acc                float64
# pub_rec_bankruptcies    float64
# tax_liens               float64
# disbursement_method       int64
# issue_month              object
# issue_year                int64
# earliest_cr_year          int64
# credit_history            int64
# dtype: object

# %%
X = df_minor_upsmapled.drop("loan_status", axis = 1)
Y = df_minor_upsmapled.loan_status

# %%
Y = LabelEncoder().fit_transform(Y)

# %% [markdown]
# ## Comenzamos el estudio con semilla 0

# %% [markdown]
# #### Separamos los conjuntos X e Y en training y testing mediante la función train_test_split(). Para ello vamos a utilizar la semilla 0 y un tamaño de testing del 25%

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=0)

# %% [markdown]
# #### Veamos ahora qué tipo de variables tenemos en xtrain. Nos interesa tener las variables en formato numérico para poder hacer el posterior análisis mediante un árbol de decisión.

# %%
xtrain.dtypes
# Out:
# loan_amnt               float64
# funded_amnt             float64
# funded_amnt_inv         float64
# term                      int64
# int_rate                float64
# installment             float64
# grade                    object
# sub_grade                object
# emp_length                int64
# home_ownership           object
# annual_inc              float64
# verification_status       int64
# purpose                  object
# addr_state               object
# dti                     float64
# delinq_2yrs             float64
# fico_range_low          float64
# fico_range_high         float64
# open_acc                float64
# pub_rec                 float64
# revol_bal               float64
# revol_util              float64
# total_acc               float64
# initial_list_status       int64
# application_type          int64
# acc_open_past_24mths    float64
# mort_acc                float64
# pub_rec_bankruptcies    float64
# tax_liens               float64
# disbursement_method       int64
# issue_month              object
# issue_year                int64
# earliest_cr_year          int64
# credit_history            int64
# dtype: object

# %%
xtrain.describe()
# Out:
#            loan_amnt    funded_amnt  funded_amnt_inv           term  \
# count  527828.000000  527828.000000    527828.000000  527828.000000
# mean    14908.606213   14908.606213     14902.696015      43.586517
# std      8493.332604    8493.332604      8489.837090      11.158916
# min      1000.000000    1000.000000       900.000000      36.000000
# 25%      8225.000000    8225.000000      8225.000000      36.000000
# 50%     13175.000000   13175.000000     13175.000000      36.000000
# 75%     20000.000000   20000.000000     20000.000000      60.000000
# max     40000.000000   40000.000000     40000.000000      60.000000
#
#             int_rate    installment     emp_length    annual_inc  \
# count  527828.000000  527828.000000  527828.000000  5.278280e+05
# mean       14.072943     445.751804       5.697413  7.324279e+04
# std         4.565485     249.899654       3.736866  6.983832e+04
# min         5.320000      14.010000       0.000000  1.000000e+02
# 25%        10.990000     266.060000       2.000000  4.500000e+04
# 50%        13.670000     386.180000       6.000000  6.200000e+04
# 75%        16.990000     582.080000      10.000000  8.800000e+04
# max        30.990000    1587.230000      10.000000  8.900060e+06
#
#        verification_status            dti  ...  initial_list_status  \
# count        527828.000000  527828.000000  ...        527828.000000
# mean              0.267265      19.167385  ...             0.560042
# std               0.442532       8.771095  ...             0.496382
# min               0.000000       0.000000  ...             0.000000
# 25%               0.000000      12.760000  ...             0.000000
# 50%               0.000000      18.740000  ...             1.000000
# 75%               1.000000      25.300000  ...             1.000000
# max               1.000000     999.000000  ...             1.000000
#
#        application_type  acc_open_past_24mths       mort_acc  \
# count     527828.000000         527828.000000  527828.000000
# mean           0.001870              5.018891       1.654880
# std            0.043202              3.227543       2.024245
# min            0.000000              0.000000       0.000000
# 25%            0.000000              3.000000       0.000000
# 50%            0.000000              5.000000       1.000000
# 75%            0.000000              7.000000       3.000000
# max            1.000000             53.000000      34.000000
#
#        pub_rec_bankruptcies      tax_liens  disbursement_method  \
# count         527828.000000  527828.000000        527828.000000
# mean               0.151765       0.058009             0.000025
# std                0.403533       0.403209             0.004963
# min                0.000000       0.000000             0.000000
# 25%                0.000000       0.000000             0.000000
# 50%                0.000000       0.000000             0.000000
# 75%                0.000000       0.000000             0.000000
# max               12.000000      85.000000             1.000000
#
#           issue_year  earliest_cr_year  credit_history
# count  527828.000000     527828.000000   527828.000000
# mean     2014.608869       1998.380552       16.228317
# std         0.626757          7.442686        7.414240
# min      2014.000000       1944.000000        3.000000
# 25%      2014.000000       1995.000000       11.000000
# 50%      2015.000000       2000.000000       15.000000
# 75%      2015.000000       2003.000000       20.000000
# max      2017.000000       2014.000000       70.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# #### Veamos qué columnas son de tipo object y cuales de tipo entero y float

# %%
num_xtrain = xtrain.select_dtypes(include=['int64', 'float64']).columns
cat_xtrain = xtrain.select_dtypes(include=['object']).columns

# %% [markdown]
# #### Dado que tenemos que modificar las columnas de tipo object, haremos uso del one hot encoding para convertirlas a numéricas. Este cambio se hace añadiendo columnas nuevas al data frame. Estas columnas tomarán únicamente los valores 1 o 0 dependiendo de si el individuo tiene una categoria determinada o no.

# %%
ohe = ce.OneHotEncoder(cols=cat_xtrain)
model = ohe.fit(xtrain)

# %%
x_train_t = model.transform(xtrain)
x_train_t
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 405387    13000.0      13000.0          13000.0    60      7.89       262.91
# 234295    10000.0      10000.0          10000.0    36     11.99       332.10
# 312077    25000.0      25000.0          25000.0    60      9.17       521.03
# 292927    35000.0      35000.0          35000.0    60     16.99       869.66
# 158822    35000.0      35000.0          35000.0    36     20.49      1309.49
# ...           ...          ...              ...   ...       ...          ...
# 1429      12000.0      12000.0          11750.0    36     10.91       392.36
# 373782    18000.0      18000.0          18000.0    60      9.99       382.36
# 412304    12000.0      12000.0          12000.0    60     16.55       295.34
# 92961     25000.0      25000.0          25000.0    60     14.99       594.62
# 237061    30000.0      30000.0          30000.0    60     17.86       759.52
#
#         grade_1  grade_2  grade_3  grade_4  ...  issue_month_6  issue_month_7  \
# 405387        1        0        0        0  ...              0              0
# 234295        0        1        0        0  ...              0              0
# 312077        0        0        1        0  ...              0              0
# 292927        0        0        0        1  ...              0              0
# 158822        0        0        0        0  ...              0              0
# ...         ...      ...      ...      ...  ...            ...            ...
# 1429          0        0        1        0  ...              0              0
# 373782        0        0        1        0  ...              0              0
# 412304        0        0        0        1  ...              0              0
# 92961         0        1        0        0  ...              0              0
# 237061        0        0        0        1  ...              0              0
#
#         issue_month_8  issue_month_9  issue_month_10  issue_month_11  \
# 405387              0              0               0               0
# 234295              0              0               0               0
# 312077              0              0               0               0
# 292927              0              0               0               0
# 158822              0              0               0               0
# ...               ...            ...             ...             ...
# 1429                0              0               1               0
# 373782              0              0               0               1
# 412304              0              0               0               0
# 92961               0              0               0               0
# 237061              0              0               0               0
#
#         issue_month_12  issue_year  earliest_cr_year  credit_history
# 405387               0        2015              2002              13
# 234295               0        2015              1997              18
# 312077               0        2015              1992              23
# 292927               0        2015              1990              25
# 158822               0        2014              1998              16
# ...                ...         ...               ...             ...
# 1429                 0        2017              2003              14
# 373782               0        2015              2001              14
# 412304               0        2015              2002              13
# 92961                1        2014              1985              29
# 237061               0        2015              2002              13
#
# [527828 rows x 151 columns]

# %% [markdown]
# ## Aplicamos

# %%
clf = tree.DecisionTreeClassifier()

# %%
sel_ridge = SelectFromModel(clf, threshold = 1e-4)
sel_ridge.fit(x_train_t, ytrain)
# Out:
# SelectFromModel(estimator=DecisionTreeClassifier(), threshold=0.0001)

# %%
df_coeficientes = pd.DataFrame(
                        {'predictor': x_train_t.columns,
                         'coef': sel_ridge.estimator_.feature_importance.flatten()}
                  )

fig, ax = plt.subplots(figsize=(16, 3.84))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('variable')
ax.set_ylabel('coeficientes')
ax.set_title('Coeficientes del modelo ridge');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3q/zfn8yb513nj10ry8w8r8_jmc0000gn/T/ipykernel_2818/699065326.py in <module>
#       1 df_coeficientes = pd.DataFrame(
#       2                         {'predictor': x_train_t.columns,
# ----> 3                          'coef': sel_ridge.estimator_.feature_importance.flatten()}
#       4                   )
#       5
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'feature_importance'

# %%
sel_ridge.estimator_
# Out:
# DecisionTreeClassifier()

# %%
list_ = list()
for i in np.arange(0.01,0.1,0.01):
    sel_ridge = SelectFromModel(clf, threshold = i)
    sel_ridge.fit(x_train_t, ytrain)
    selected_feat = x_train_t.columns[sel_ridge.get_support()]
    list_.append(len(selected_feat))

list_
# Out:
# [21, 15, 9, 6, 5, 4, 2, 1, 1]

# %%
rfe = RFE(clf, n_features_to_select=30)
fit = rfe.fit(x_train_t, ytrain)
fit.support_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3q/zfn8yb513nj10ry8w8r8_jmc0000gn/T/ipykernel_2818/3096886255.py in <module>
#       1 rfe = RFE(clf, n_features_to_select=30)
# ----> 2 fit = rfe.fit(x_train_t, ytrain)
#       3 fit.support_
#
# ~/opt/anaconda3/envs/core_models/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in fit(self, X, y, **fit_params)
#     220             Fitted estimator.
#     221         """
# --> 222         return self._fit(X, y, **fit_params)
#     223
#     224     def _fit(self, X, y, step_score=None, **fit_params):
#
# ~/opt/anaconda3/envs/core_models/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in _fit(self, X, y, step_score, **fit_params)
#     281                 print("Fitting estimator with %d features." % np.sum(support_))
#     282
# --> 283             estimator.fit(X[:, features], y, **fit_params)
#     284
#     285             # Get importance and rank them
#
# ~/opt/anaconda3/envs/core_models/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~/opt/anaconda3/envs/core_models/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Ya estamos en condiciones para introducir el modelo de árbol de decisión. Para ello necesitamos la función tree que hemos importado al principio de la práctica

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train_t, ytrain)
clf

# %% [markdown]
# #### Dibujamos el decision tree con 4 nodos de exploración máximos para que sea más fácil de visualizar

# %%
tree.plot_tree(clf, max_depth=4, filled=True, rounded=True, fontsize=5, label="none")
plt.show()

# %%
x_test_t = model.transform(xtest)
x_test_t

# %% [markdown]
# ## Comenzamos con las predicciones

# %%
predictions = clf.predict(x_test_t)
predictions

# %%
predictions_proba = clf.predict_proba(x_test_t)
predictions_proba

# %% [markdown]
# Hacemos la predicción de la cuarta fila del dataset

# %%
predict_4 = clf.predict(x_test_t)[4]
predict_4 == ytest[4]

# %%
print("Clasification report")
classification_report(ytest, predictions)

# %%
#DATAFRAME_medidas_1 = medidas(x_train_t, ytrain, x_test_t, ytest, profundidad=51)

# %%
#round(DATAFRAME_medidas_1.pct_change(),3)

# %%
#sns.lineplot(data = DATAFRAME_medidas_1)

# %% [markdown]
# ### Curva ROC

# %%
# keep probabilities for the positive outcome only
yhat = predictions_proba[:, 1]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(ytest, yhat)
# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Decision Tree')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# show the plot
plt.show()

# %% [markdown]
# ### Matriz de confusión

# %% [markdown]
# #### Mostremos además la matriz de confusión.
#
# ##### Por un lado mostraremos esta matriz en valores absolutos y, después la mostraremos en valores relativos. De esta forma podremos comparar mejor los valores obtenidos

# %%
cm_gbt = confusion_matrix(ytest, predictions)
cm_gbt_norm = confusion_matrix(ytest, predictions, normalize="true")

plt.figure(figsize=(7,7))
sns.heatmap(cm_gbt, annot=True, fmt=".3f", linewidths=1, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
plt.title("Confusion matrix")

plt.figure(figsize=(7,7))
sns.heatmap(cm_gbt_norm, annot=True, fmt=".3f", linewidths=1, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
plt.title("Normalized confusion matrix")

# %% [markdown]
# ## Cambiamos de semilla a 12345.

# %% [markdown]
# #### Cambiamos la semilla de 0 a 12345. Realizaremos los mismos cálculos y compararemos los resultados obtenidos con ambas semillas

# %%
xtrain_2, xtest_2, ytrain_2, ytest_2 = train_test_split(X, Y, test_size=0.25, random_state=12345)

# %%
xtrain_2.dtypes

# %%
xtrain_2.describe()

# %%
num_xtrain_2 = xtrain_2.select_dtypes(include=['int64', 'float64']).columns
cat_xtrain_2 = xtrain_2.select_dtypes(include=['object']).columns

# %% [markdown]
# ##### Ahora pasamos las variables categóricas a one hot encoding

# %%
ohe_2 = ce.OneHotEncoder(cols=cat_xtrain_2)
model_2 = ohe_2.fit(xtrain_2)

# %%
x_train_t_2 = model_2.transform(xtrain_2)
x_train_t_2

# %%
x_test_t_2 = model_2.transform(xtest_2)
x_test_t_2

# %%
clf_2 = tree.DecisionTreeClassifier()
clf_2 = clf_2.fit(x_train_t_2, ytrain_2)
clf_2

# %% [markdown]
# #### Dibujamos el decision tree con 4 nodos de exploración máximos para que sea más fácil de visualizar

# %%
tree.plot_tree(clf, max_depth=4, filled=True, rounded=True, fontsize=5, label="none")
plt.show()

# %%
x_test_t_2 = model_2.transform(xtest_2)
x_test_t_2

# %% [markdown]
# ## Comenzamos con las predicciones para nuestra nueva semilla

# %%
predictions_2 = clf_2.predict(x_test_t_2)
predictions_2

# %%
predictions_proba_2 = clf_2.predict_proba(x_test_t_2)
predictions_proba_2

# %% [markdown]
# #### Hacemos la predicción de la cuarta fila del dataset

# %%
predict_4_2 = clf_2.predict(x_test_t_2)[4]
predict_4_2 == ytest_2[4]

# %%
print("Clasification report")
classification_report(ytest_2, predictions_2)

# %% [markdown]
# ### Calculamos el data frame de las medidas

# %%
#DATAFRAME_medidas_2 = medidas(x_train_t_2, x_test_t=x_test_t_2, ytrain=ytrain_2, ytest=ytest_2, profundidad=31)

# %%
#round(DATAFRAME_medidas_2.pct_change(),3)

# %%
#sns.lineplot(data = DATAFRAME_medidas_2)

# %% [markdown]
# ### Curva ROC

# %%
# keep probabilities for the positive outcome only
yhat_2 = predictions_proba_2[:, 1]
# calculate roc curves
fpr_2, tpr_2, thresholds_2 = roc_curve(ytest_2, yhat_2)
# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr_2, tpr_2, marker='.', label='Decision Tree')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# show the plot
plt.show()

# %% [markdown]
# ### Matriz de confusión

# %% [markdown]
# #### Mostremos además la matriz de confusión.
#
# #### Por un lado mostraremos esta matriz en valores absolutos y, después la mostraremos en valores relativos. De esta forma podremos comparar mejor los valores obtenidos

# %%
cm_gbt_2 = confusion_matrix(ytest_2, predictions_2)
cm_gbt_norm_2 = confusion_matrix(ytest_2, predictions_2, normalize="true")

plt.figure(figsize=(7,7))
sns.heatmap(cm_gbt_2, annot=True, fmt=".3f", linewidths=1, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
plt.title("Confusion matrix")

plt.figure(figsize=(7,7))
sns.heatmap(cm_gbt_norm_2, annot=True, fmt=".3f", linewidths=1, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
plt.title("Normalized confusion matrix")

# %% [markdown]
# #### Creamos ahora un data frame en el que se muestra la medida F1 y los valores de accuracy y precision tanto para la semilla 0 como para la semilla 12345. También mostraremos las diferencias en porcentaje

# %%
p1 = precision_score(ytest, predictions)
p2 = precision_score(ytest_2, predictions_2)
f1 = f1_score(ytest, predictions)
f2 = f1_score(ytest_2, predictions_2)
ac1 = accuracy_score(ytest, predictions)
ac2 = accuracy_score(ytest_2, predictions_2)

dict_medidas = {'F1': [f1, f2, (abs(f1-f2)/max(f1,f2))*100], "accuracy" :[ac1, ac2, (abs(ac1-ac2)/max(ac1,ac2))*100], 
        'precision': [p1, p2, (abs(p1-p2)/max(p1,p2))*100]
       }
    
pd.DataFrame(dict_medidas, columns=["F1", "precision", 'accuracy'], index = ["semilla 0", "semilla 12345", 'diff %'])

# %% [markdown]
# #### Haciendo uso de la función evaluate_model creada al principio, podemos ver las diferentes medidas obtenidas para la semilla 0 y para la semilla 12345

# %%
evaluate_model(ytest, predictions, ypred_proba = predictions_proba)

# %%
evaluate_model(ytest_2, predictions_2, ypred_proba = predictions_proba_2)
